# %% [markdown]
# # Environment

# %%
# Import required libraries
import loompy
import numpy as np
import pandas as pd
import gc  # for garbage collection
import os
import seaborn as sns
import matplotlib.pyplot as plt
from typing import Dict, List
import warnings
warnings.filterwarnings('ignore')

# Set working directory
os.chdir('/beegfs/scratch/ric.broccoli/kubacki.michal/SRF_SRRM3_dev/Mousebrain')

# Add local_functions directory to Python path
from local_functions import *

# Set plotting style
plt.style.use('default')  # Use default matplotlib style
sns.set_theme()  # Apply seaborn styling
sns.set_palette("husl")

# %%
loom_path = "/beegfs/scratch/ric.broccoli/kubacki.michal/SRF_SRRM3_dev/Mousebrain/DATA/dev_all.loom"

# %%
# Verify file exists
print(f"File exists: {os.path.exists(loom_path)}")
print(f"File size: {os.path.getsize(loom_path) / (1024**3):.2f} GB")
# Out:
# File exists: True
# File size: 9.56 GB

# %%
# Create plots directory if it doesn't exist
os.makedirs('plots_sc', exist_ok=True)

# %% [markdown]
# # Define functions

# %% [markdown]
# **Column attributes**
# - Age: object
# - BTSNE: float64
# - CellCycle: float64
# - CellID: object
# - Cell_Conc: int64
# - Chemistry: object
# - ChipID: object
# - Class: object
# - ClusterName: object
# - Clusters: int64
# - Date_Captured: object
# - DonorID: object
# - DoubletFinderPCA: float64
# - HPF: float64
# - HPF_LogPP: float64
# - HPF_theta: float64
# - IsCycling: uint8
# - Label: object
# - Location_E9_E11: object
# - NCellsCluster: int64
# - NGenes: float64
# - Num_Pooled_Animals: int64
# - PCA: float64
# - PCR_Cycles: int64
# - Plug_Date: object
# - Project: object
# - PseudoAge: float64
# - PseudoTissue: object
# - Region: object
# - SampleID: object
# - SampleName: object
# - Sample_Index: object
# - Sex: object
# - Species: object
# - Split: int64
# - Strain: object
# - Subclass: object
# - TSNE: float64
# - Target_Num_Cells: float64
# - Tissue: object
# - TotalUMI: float64
# - Transcriptome: object
# - UMAP: float32
# - UMAP3D: float32
# - cDNA_Lib_Ok: object
# - ngperul_cDNA: object

# %% [markdown]
# # Data exploration

# %% [markdown]
# ## Expression format

# %%
ds = loompy.connect(loom_path)
matrix = ds[:, :]
print("Matrix shape:", matrix.shape)
print("Value range:", np.min(matrix), "-", np.max(matrix))
print("Zero proportion:", np.sum(matrix == 0) / matrix.size)
print("Mean expression:", np.mean(matrix))
print("Mean expression (excluding zeros):", np.mean(matrix[matrix > 0]))
# Out:
# Matrix shape: (31053, 292495)
# Value range: 0.0 - 16039.0
# Zero proportion: 0.9190015037173528
# Mean expression: 0.2256014
# Mean expression (excluding zeros): 2.787288

# %%
plt.figure(figsize=(8,4))
sns.histplot(matrix[matrix > 0].flatten(), bins=50, log=True)
plt.xlabel('Expression values')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Get Srrm3 index
srrm3_idx = np.where(ds.ra.Gene == 'Srrm3')[0][0]
srrm3_expr = matrix[srrm3_idx, :]

plt.figure(figsize=(8,4))
sns.histplot(srrm3_expr[srrm3_expr > 0], bins=30)
plt.xlabel('Srrm3 expression')
plt.ylabel('Count')

# Calculate mean expression excluding zeros
srrm3_mean_nonzero = np.mean(srrm3_expr[srrm3_expr > 0])
print(f"Mean Srrm3 expression (excluding zeros): {srrm3_mean_nonzero:.3f}")
# Out:
# Mean Srrm3 expression (excluding zeros): 1.555

# %%
# Calculate proportion of non-zero expression
srrm3_expressed = np.sum(srrm3_expr > 0) / len(srrm3_expr)
print(f"Srrm3 is expressed in {srrm3_expressed:.2%} of samples")
# Out:
# Srrm3 is expressed in 19.65% of samples

# %%
examine_loom_file(loom_path)
# Out:
# Dataset shape: (31053, 292495)
# Number of cells: 292,495
# Number of genes: 31,053
#
# Column attributes (cell metadata):
# - Age: object
# - BTSNE: float64
# - CellCycle: float64
# - CellID: object
# - Cell_Conc: int64
# - Chemistry: object
# - ChipID: object
# - Class: object
# - ClusterName: object
# - Clusters: int64
# - Date_Captured: object
# - DonorID: object
# - DoubletFinderPCA: float64
# - HPF: float64
# - HPF_LogPP: float64
# - HPF_theta: float64
# - IsCycling: uint8
# - Label: object
# - Location_E9_E11: object
# - NCellsCluster: int64
# - NGenes: float64
# - Num_Pooled_Animals: int64
# - PCA: float64
# - PCR_Cycles: int64
# - Plug_Date: object
# - Project: object
# - PseudoAge: float64
# - PseudoTissue: object
# - Region: object
# - SampleID: object
# - SampleName: object
# - Sample_Index: object
# - Sex: object
# - Species: object
# - Split: int64
# - Strain: object
# - Subclass: object
# - TSNE: float64
# - Target_Num_Cells: float64
# - Tissue: object
# - TotalUMI: float64
# - Transcriptome: object
# - UMAP: float32
# - UMAP3D: float32
# - cDNA_Lib_Ok: object
# - ngperul_cDNA: object
#
# Row attributes (gene metadata):
# - Accession: object
# - Chromosome: object
# - End: int64
# - Gamma: float64
# - Gene: object
# - HPF: float64
# - HPF_beta: float64
# - MultilevelMarkers: float64
# - Selected: int64
# - Start: int64
# - Strand: object
# - Valid: int64
#
# Sample of expression matrix (5x5):
# [[ 0.  0.  0.  1.  0.]
#  [ 0.  2.  0.  3.  7.]
#  [ 0.  0.  0.  0.  0.]
#  [ 0. 11.  7.  2.  8.]
#  [ 1.  1.  0.  0.  1.]]
#
# Basic statistics:
# Mean expression: 1.7600
# Median expression: 0.0000
# Sparsity: 56.00%

# %%
data = get_data(loom_path, 'Srrm3')

# %%
data_df = pd.DataFrame(data)

# %%
def create_pseudo_cells(df, group_by_column):
    """
    Create pseudo-cells by aggregating data grouped by a specific column.
    
    Parameters:
    -----------
    df : pandas.DataFrame
        Input dataframe containing single-cell data
    group_by_column : str
        Column name to group the cells by
        
    Returns:
    --------
    pandas.DataFrame
        Aggregated pseudo-cell data with mean/median values for numeric columns
    """
    # Numeric columns to aggregate
    numeric_cols = ['PseudoAge', 'Expression', 'TotalUMI', 'NGenes']
    
    # Initialize aggregation dictionary with numeric columns
    agg_dict = {
        'PseudoAge': 'mean',  # Average pseudo age
        'Expression': 'mean',  # Average expression
        'TotalUMI': 'mean',  # Average UMI count
        'NGenes': 'mean',  # Average number of genes
        'CellID': 'count'  # Count of cells in each group
    }
    
    # Add categorical columns to aggregation dict, excluding the grouping column
    categorical_cols = ['Tissue', 'Sex', 'Subclass', 'Region', 'Age', 'Class']
    for col in categorical_cols:
        if col in df.columns and col != group_by_column:
            agg_dict[col] = lambda x: x.mode().iloc[0]
    
    # Group by the specified column and aggregate
    pseudo_cells = df.groupby(group_by_column).agg(agg_dict).reset_index()
    
    # Rename the CellID column to CellCount
    pseudo_cells = pseudo_cells.rename(columns={'CellID': 'CellCount'})
    
    # Round numeric columns to 2 decimal places
    for col in numeric_cols:
        if col in pseudo_cells.columns:
            pseudo_cells[col] = pseudo_cells[col].round(2)
            
    return pseudo_cells

# %%
data_df.head()
# Out:
#     Age                   Tissue Sex           Subclass         Class Region  \
# 0  e7.0  All (No extraembryonal)   ?  Parietal endoderm  Gastrulation   Head
# 1  e7.0  All (No extraembryonal)   ?  Parietal endoderm  Gastrulation   Head
# 2  e7.0  All (No extraembryonal)   ?  Parietal endoderm  Gastrulation   Head
# 3  e7.0  All (No extraembryonal)   ?  Parietal endoderm  Gastrulation   Head
# 4  e7.0  All (No extraembryonal)   ?  Parietal endoderm  Gastrulation   Head
#
#    PseudoAge  Expression                       CellID ClusterName  TotalUMI  \
# 0      7.050         0.0  10X39_2_A_1:AAACTTGAGAGCAGx     ParEndo    2189.0
# 1      9.220         0.0  10X39_3_A_1:AAGTTCCTAGCCTAx     ParEndo    2757.0
# 2      9.265         0.0  10X39_2_A_1:GGGACCACAGCGTTx     ParEndo    4941.0
# 3      9.545         0.0  10X39_2_A_1:CAGCAATGGGTAGGx     ParEndo    8176.0
# 4      8.685         0.0  10X39_3_A_1:CAGCCTACAGAGATx     ParEndo   16640.0
#
#    NGenes
# 0  1032.0
# 1  1436.0
# 2  1831.0
# 3  2559.0
# 4  4084.0

# %%
# Print unique values for each column
print("Age:", list(data_df.Age.unique()))
print("Tissue:", list(data_df.Tissue.unique()))
print("Sex:", list(data_df.Sex.unique()))
print("Subclass:", list(data_df.Subclass.unique()))
print("Class:", list(data_df.Class.unique()))
print("Region:", list(data_df.Region.unique()))
print("PseudoAge:", list(data_df.PseudoAge.unique()))
print("ClusterName:", list(data_df.ClusterName.unique()))
# Out:
# Age: ['e7.0', 'e8.0', 'e8.5', 'e11.0', 'e9.0', 'e10.0', 'e18.0', 'e13.5', 'e12.5', 'e12.0', 'e14.5', 'e17.0', 'e15.0', 'e14.0', 'e16.0', 'e16.5', 'e15.5', 'e13.0', 'e17.5', 'e16.25']
# Tissue: ['All (No extraembryonal)', 'Head', 'Hindbrain', 'Forebrain', 'Midbrain', 'ForebrainDorsal', 'ForebrainVentroLateral', 'ForebrainVentral', 'ForebrainVentroThalamic', 'MidbrainVentral', 'MidbrainDorsal']
# Sex: ['?']
# Subclass: ['Parietal endoderm', 'Undefined', 'Extraembryonic ectoderm', 'Endoderm', 'Visceral endoderm', 'Extraembryonic endoderm', 'Cardiac mesoderm', 'Osteochondral mesoderm', 'Mesoderm', 'Hematoendothelial lineage', 'Mesenchyme', 'Nascent mesoderm', 'Primordial germ cells', 'Epiblast', 'Definitive endoderm', 'Anterior primitive streak', 'Node', 'Early choroid plexus', 'Fourth-ventricle roof plate', 'Floor plate', 'Caudal', 'Anterior', 'Optic cup', 'Neuromesodermal progenitors', 'Cardiac', 'Paraxial', 'Pharyngeal', 'Neural crest', 'Gut', 'Early ectoderm', 'Dorsal early ectoderm', 'Surface ectoderm', 'Otic vesicle', 'Pharyngeal epithelium', 'Oral ectoderm', 'Lens', 'Adenohypophyseal placode', 'Lateral nasal pit', 'Olfactory pit', 'Olfactory epithelium', 'Erythrocyte', 'Erythroid progenitor', 'Chondrocytes', 'Early fibroblasts', 'Perivascular fibroblast-like cells', 'Pia 1', 'Pia 2', 'Pia 3', 'Intermediate meninges 1', 'Dura', 'Arachnoid barrier cells', 'Intermediate meninges 2', 'Arachnoid', 'Pericyte', 'Vascular smooth muscle', 'Endothelial', 'Angioblast', 'Axon tract-associated microglia', 'Cycling microglia', 'Non-cycling microglia', 'Non-cycling perivascular macrophages', 'Cycling perivascular macrophages', 'Early macrophage', 'Infiltrating immune', 'Platelet', 'Forebrain astrocyte', 'Forebrain', 'Dorsal forebrain', 'Cortical hem', 'Midbrain-hindbrain boundary', 'Ventral hindbrain', 'Ventral midbrain', 'Dorsal midbrain', 'Hindbrain roof plate', 'Dorsal hindbrain', 'Midbrain basal plate', 'Midbrain floor plate', 'Hindbrain floor plate', 'Hypothalamic floor-plate like', 'Zona limitans intrathalamica', 'Roof plate', 'Anteromedial cerebral pole', 'Dorsal diencephalon', 'Mixed region', 'Midbrain', 'Hindbrain', 'Choroid plexus', 'Spinal cord', 'Ependymal-like', 'Hypothalamus', 'Late isthmic organizer', 'Bergmann glia', 'Dorsal hindbrain and spinal cord', 'Pineal gland', 'Diencephalon', 'Diencephalic roof plate', 'Subcommissural organ hypendymal cell', 'Olfactory ensheathing cell', 'Schwann cell', 'Mixed region astrocytes', 'PreOPC', 'Oligodendrocyte precursor cell', 'Committed oligodendrocyte precursor', 'Oligodendrocyte', 'Midbrain GABAergic', 'Forebrain glutamatergic', 'Forebrain GABAergic', 'Cajal-Retzius', 'Motor neuron', 'Mixed region glutamatergic', 'Midbrain glutamatergic', 'Hindbrain glycinergic', 'Sensory neuron', 'Hindbrain glutamatergic', 'Spinal cord glutamatergic', 'Hindbrain GABAergic', 'Thalamus glutamatergic', 'Neuronal intermediate progenitor', 'Cortical or hippocampal glutamatergic', 'Midbrain-hindbrain GABAergic', 'Spinal cord glycinergic', 'Hypothalamus glutamatergic', 'Hindbrain serotoninergic', 'Midbrain dopaminergic', 'Mixed region and neurotransmitter', 'Mixed region GABAergic', 'Cerebellum GABAergic', 'Posterior hindbrain glutamatergic', 'Dorsal midbrain glutamatergic', 'Cerebellum glutamatergic', 'Epithalamus glutamatergic', 'Diencephalon glutamatergic', 'Pituitary neuroendocrine']
# Class: ['Gastrulation', 'Radial glia', 'Mesenchyme', 'Neural tube', 'Mesoderm', 'Neural crest', 'Bad cells', 'Endoderm', 'Ectoderm', 'Blood', 'Fibroblast', 'Vascular', 'Immune', 'Glioblast', 'Choroid plexus', 'Ependymal', 'Pineal gland', 'Subcommissural organ', 'Olfactory ensheathing cell', 'Schwann cell', 'Oligodendrocyte', 'Neuroblast', 'Undefined', 'Neuron']
# ClusterName: ['ParEndo', 'nan', 'TrophEct', 'FGut4', 'FGut1', 'FGut3', 'FGut2', 'VEnd1', 'VEnd3', 'VEnd2', 'ExVE5', 'ExVE4', 'ExVE3', 'ExVE2', 'ExVE1', 'CardCres', 'MesPer', 'MesOst', 'Mesod4', 'Mesod3', 'Mesod5', 'Mesod6', 'CardCr', 'Mesn1', 'HemEndPr1', 'HemEndPr2', 'HematProg', 'Mesod2', 'Mesod1', 'GermC', 'Epi1', 'Epi2', 'Epi3', 'DVE1', 'DVE2', 'DVE3', 'AEMeso', 'ChorProg', 'RglHB1', 'Mesn2', 'Mesn3', 'Mesn4', 'Mesn5', 'Mesn6', 'Mesn7', 'Mesn8', 'Mesn9', 'NEpit1', 'NEpit4', 'NEpit3', 'NEpit2', 'NMP', 'MesnPhar1', 'PxMeso2', 'PxMeso1', 'NeurCrest2', 'NeurCrest1', 'PxMeso3', 'Ectoderm5', 'Ectoderm3', 'Ectoderm4', 'Ectoderm1', 'Ectoderm2', 'Surfecto', 'OticV', 'PharEpi', 'OrEcto1', 'LensEcto', 'OrEcto2', 'Ectoderm6', 'NasPitL', 'OlfPit1', 'OlfPit2', 'OlfEpit', 'Ery1', 'Ery2', 'Ery3', 'Ery4', 'Ery5', 'EryProg1', 'EryProg2', 'EryProg3', 'EryProg4', 'EryProg5', 'Chondro', 'FibroE1', 'FibroE2', 'FibroE3', 'FibroPV', 'Pia1', 'Pia2', 'Pia3', 'Meninges1', 'Dura', 'ABC', 'Meninges2', 'Arachnoid', 'Peric1', 'Peric2', 'VSM1', 'VSM2', 'Vendo1', 'Vendo2', 'Vendo3', 'Vendo4', 'Vendo5', 'Vendo6', 'Vendo7', 'Vendo8', 'Vendo9', 'Vendo10', 'Angiob2', 'Angiob3', 'MglATA', 'MglCyc', 'Mgl', 'Pvm3', 'PvmCyc', 'MacroE', 'Neutroph', 'Mono', 'Macro', 'MastBaso', 'Immune1', 'Tcell', 'Platelet', 'AstroF', 'GblF1', 'GblF2', 'GblF3', 'GblF4', 'GblF5', 'GblF6', 'GblF7', 'RglDF1', 'RglDF2', 'RglDF3', 'RglDF4', 'RglDF5', 'RglDF6', 'RglDF7', 'RglDF8', 'RglDF9', 'RglDF10', 'RglDF11', 'RglDF12', 'RglDF13', 'RglDF14', 'RglDF15', 'RglCH1', 'RglMHB1', 'RglMHB2', 'RglMHB3', 'RglMHB4', 'RglVM1', 'RglVM2', 'RglDM1', 'RglHRP', 'RglDH1', 'RglDH2', 'RglMBP', 'RglMFP', 'RglHFP', 'RglHypFP', 'RglF1', 'RglF2', 'RglZLI', 'RglRP', 'RglCH2', 'RglACP', 'RglF3', 'RglF4', 'RglF5', 'RglF6', 'RglF7', 'RglF8', 'RglF9', 'RglF10', 'RglF11', 'RglF12', 'RglF13', 'Rgl
# %%
plt.figure(figsize=(10, 6))
plt.hist(data_df.PseudoAge, bins=30, edgecolor='black')
plt.xlabel('PseudoAge')
plt.ylabel('Frequency')
plt.title('Distribution of PseudoAge')
plt.show()

# %%
# Create 10 bins for PseudoAge
min_age = data_df.PseudoAge.min()
max_age = data_df.PseudoAge.max()
bin_size = (max_age - min_age) / 10

# Create bins
bins = [min_age + i * bin_size for i in range(11)]

# Create new column with binned PseudoAge
data_df['PseudoAge_Binned'] = pd.cut(data_df.PseudoAge, bins=bins, labels=list(range(1,11)))

# %%
plt.figure(figsize=(10, 6))
plt.hist(data_df.PseudoAge_Binned.astype(str), bins=10, edgecolor='black')
plt.xlabel('PseudoAge')
plt.ylabel('Frequency')
plt.title('Distribution of PseudoAge')
plt.show()

# %% [markdown]
# # Data subsets

# %%
type(data_df.Subclass)
# Out:
# pandas.core.series.Series

# %%
data_df_forebrain_dorsal = data_df[data_df.Tissue == 'ForebrainDorsal']
print(data_df_forebrain_dorsal.shape)
# Out:
# (49370, 13)

# %%
print(list(data_df_forebrain_dorsal.Subclass.unique()))

print(list(data_df_forebrain_dorsal.Class.unique()))
# Out:
# ['Epiblast', 'Fourth-ventricle roof plate', 'Mesenchyme', 'Undefined', 'Caudal', 'Optic cup', 'Neural crest', 'Surface ectoderm', 'Lateral nasal pit', 'Olfactory pit', 'Olfactory epithelium', 'Erythrocyte', 'Erythroid progenitor', 'Chondrocytes', 'Early fibroblasts', 'Perivascular fibroblast-like cells', 'Pia 1', 'Pia 2', 'Pia 3', 'Intermediate meninges 1', 'Dura', 'Intermediate meninges 2', 'Arachnoid', 'Pericyte', 'Vascular smooth muscle', 'Endothelial', 'Angioblast', 'Axon tract-associated microglia', 'Cycling microglia', 'Non-cycling microglia', 'Non-cycling perivascular macrophages', 'Cycling perivascular macrophages', 'Early macrophage', 'Infiltrating immune', 'Platelet', 'Forebrain astrocyte', 'Forebrain', 'Dorsal forebrain', 'Cortical hem', 'Midbrain-hindbrain boundary', 'Ventral midbrain', 'Dorsal midbrain', 'Hypothalamic floor-plate like', 'Roof plate', 'Anteromedial cerebral pole', 'Dorsal diencephalon', 'Mixed region', 'Midbrain', 'Choroid plexus', 'Spinal cord', 'Hypothalamus', 'Hindbrain', 'Dorsal hindbrain', 'Pineal gland', 'Diencephalon', 'Diencephalic roof plate', 'Olfactory ensheathing cell', 'Schwann cell', 'Mixed region astrocytes', 'PreOPC', 'Oligodendrocyte precursor cell', 'Midbrain GABAergic', 'Forebrain glutamatergic', 'Forebrain GABAergic', 'Cajal-Retzius', 'Mixed region glutamatergic', 'Midbrain glutamatergic', 'Sensory neuron', 'Hindbrain glutamatergic', 'Thalamus glutamatergic', 'Neuronal intermediate progenitor', 'Cortical or hippocampal glutamatergic', 'Hindbrain glycinergic', 'Hindbrain GABAergic', 'Hypothalamus glutamatergic', 'Mixed region and neurotransmitter', 'Mixed region GABAergic', 'Dorsal midbrain glutamatergic', 'Epithalamus glutamatergic', 'Diencephalon glutamatergic']
# ['Gastrulation', 'Radial glia', 'Mesenchyme', 'Neural tube', 'Neural crest', 'Bad cells', 'Ectoderm', 'Blood', 'Fibroblast', 'Vascular', 'Immune', 'Glioblast', 'Choroid plexus', 'Ependymal', 'Pineal gland', 'Olfactory ensheathing cell', 'Schwann cell', 'Oligodendrocyte', 'Neuroblast', 'Undefined', 'Neuron']

# %%
data_df_forebrain_dorsal[data_df_forebrain_dorsal.Class.isin(['Gastrulation', 'Neural tube', 'Neural crest', 'Neuroblast', 'Neuron'])]['Class'].value_counts()
# Out:
# Class
# Neuron          22960
# Neuroblast      11761
# Neural tube         3
# Gastrulation        1
# Neural crest        1
# Name: count, dtype: int64

# %%
data_df_forebrain_dorsal_neurons = data_df_forebrain_dorsal[data_df_forebrain_dorsal.Class.isin(['Neuron'])]

# %% [markdown]
# # Plots

# %% [markdown]
# ## Cell type expression

# %%
plot_cell_type_expression(data_df_forebrain_dorsal[data_df_forebrain_dorsal.Class.isin(['Neuroblast', 'Neuron'])])

# %%
pseudo_cells_by_class = create_pseudo_cells(data_df_forebrain_dorsal[data_df_forebrain_dorsal.Class.isin(['Neuroblast', 'Neuron'])], 'Class')
pseudo_cells_by_class.head()
# Out:
#         Class  PseudoAge  Expression  TotalUMI   NGenes  CellCount  \
# 0  Neuroblast      14.44        0.20   4598.79  2163.60      11761
# 1      Neuron      15.57        0.42   4964.57  2271.88      22960
#
#             Tissue Sex                               Subclass     Region  \
# 0  ForebrainDorsal   ?       Neuronal intermediate progenitor  Forebrain
# 1  ForebrainDorsal   ?  Cortical or hippocampal glutamatergic  Forebrain
#
#      Age
# 0  e15.0
# 1  e15.0

# %% [markdown]
# ## Temporal expression

# %%
print("Age value counts:")
print(data_df_forebrain_dorsal_neurons.Age.value_counts())
print("\nPseudoAge_Binned value counts:")
print(data_df_forebrain_dorsal_neurons.PseudoAge_Binned.value_counts())
# Out:
# Age value counts:
# Age
# e15.0     4968
# e18.0     3412
# e17.0     2376
# e16.5     2319
# e14.5     2031
# e17.5     1893
# e15.5     1667
# e12.0     1400
# e16.25    1282
# e13.5     1092
# e12.5      520
# Name: count, dtype: int64
#
# PseudoAge_Binned value counts:
# PseudoAge_Binned
# 9     7882
# 8     7394
# 10    3874
# 7     2950
# 6      756
# 5      101
# 4        2
# 1        0
# 2        0
# 3        0
# Name: count, dtype: int64

# %%
plot_temporal_expression(data_df_forebrain_dorsal_neurons, "Age")

# %%
pseudo_cells_by_age = create_pseudo_cells(data_df_forebrain_dorsal_neurons, 'Age')
pseudo_cells_by_age.head()
# Out:
#      Age  PseudoAge  Expression  TotalUMI   NGenes  CellCount  \
# 0  e12.0      13.69        0.54   5220.85  2433.02       1400
# 1  e12.5      14.23        0.46   4985.39  2300.87        520
# 2  e13.5      14.73        0.48   5978.14  2485.26       1092
# 3  e14.5      14.91        0.58   6271.51  2593.34       2031
# 4  e15.0      15.14        0.39   4930.10  2276.01       4968
#
#             Tissue Sex                               Subclass     Region  \
# 0  ForebrainDorsal   ?                Forebrain glutamatergic  Forebrain
# 1  ForebrainDorsal   ?                Forebrain glutamatergic  Forebrain
# 2  ForebrainDorsal   ?  Cortical or hippocampal glutamatergic  Forebrain
# 3  ForebrainDorsal   ?  Cortical or hippocampal glutamatergic  Forebrain
# 4  ForebrainDorsal   ?  Cortical or hippocampal glutamatergic  Forebrain
#
#     Class
# 0  Neuron
# 1  Neuron
# 2  Neuron
# 3  Neuron
# 4  Neuron

# %%
plot_temporal_cell_type_heatmap(pseudo_cells_by_age,"Age")

# %%
plot_regional_expression(data_df)

# %%
pseudo_cells_by_region = create_pseudo_cells(data_df, 'Region')
pseudo_cells_by_region.head()
# Out:
#       Region  PseudoAge  Expression  TotalUMI   NGenes  CellCount  \
# 0  Forebrain      14.19        0.26   5929.33  2351.23     138419
# 1       Head       7.69        0.01  11979.60  3177.01      24026
# 2  Hindbrain      13.63        0.38   7272.81  2551.46      70781
# 3   Midbrain      13.43        0.45   7209.30  2586.79      59269
#
#                     Tissue Sex                               Subclass    Age  \
# 0          ForebrainDorsal   ?  Cortical or hippocampal glutamatergic  e12.0
# 1  All (No extraembryonal)   ?                               Epiblast   e7.0
# 2                Hindbrain   ?                              Hindbrain  e10.0
# 3                 Midbrain   ?                 Midbrain glutamatergic  e10.0
#
#           Class
# 0        Neuron
# 1  Gastrulation
# 2        Neuron
# 3        Neuron

# %%
plot_regional_expression(pseudo_cells_by_region[pseudo_cells_by_region.Class.isin(['Neuron'])])

# %%
plot_temporal_cell_type_heatmap(data_df, "Age")
plot_temporal_cell_type_heatmap(data_df, "PseudoAge")
plot_temporal_cell_type_heatmap(data_df, "PseudoAge_Binned")

# %% [markdown]
# # Statistics

# %%
# Basic statistics
print("\nSrrm3 Expression Statistics:")
print(f"Mean expression: {np.mean(data['Expression']):.4f}")
print(f"Median expression: {np.median(data['Expression']):.4f}")
print(f"Percentage of cells expressing Srrm3: {(data['Expression'] > 0).mean() * 100:.2f}%")
# Out:
# Srrm3 Expression Statistics:
# Mean expression: 0.3056
# Median expression: 0.0000
# Percentage of cells expressing Srrm3: 19.65%

# %%
# Top expressing cell types
df = pd.DataFrame({
    'Cell Type': data['Class'],
    'Expression': data['Expression']
})

print("\nTop 5 Cell Types by Mean Srrm3 Expression:")
print(df.groupby('Cell Type')['Expression']
        .agg(['mean', 'count'])
        .sort_values('mean', ascending=False)
        .head())
# Out:
# Top 5 Cell Types by Mean Srrm3 Expression:
#                      mean   count
# Cell Type
# Neuroblast       0.569348   45178
# Neuron           0.554316  111063
# Oligodendrocyte  0.145256    2203
# Undefined        0.136095     169
# Ependymal        0.052770     379
